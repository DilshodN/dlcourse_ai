# %% [markdown]
# # Задание 1.2 - Линейный классификатор (Linear classifier)
#
# В этом задании мы реализуем другую модель машинного обучения - линейный классификатор. Линейный классификатор подбирает для каждого класса веса, на которые нужно умножить значение каждого признака и потом сложить вместе.
# Тот класс, у которого эта сумма больше, и является предсказанием модели.
#
# В этом задании вы:
# - потренируетесь считать градиенты различных многомерных функций
# - реализуете подсчет градиентов через линейную модель и функцию потерь softmax
# - реализуете процесс тренировки линейного классификатора
# - подберете параметры тренировки на практике
#
# На всякий случай, еще раз ссылка на туториал по numpy:
# http://cs231n.github.io/python-numpy-tutorial/

# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %load_ext autoreload
# %autoreload 2

# %%
from dataset import load_svhn, random_split_train_val
from gradient_check import check_gradient
from metrics import multiclass_accuracy 
import linear_classifer

# %% [markdown]
# # Как всегда, первым делом загружаем данные
#
# Мы будем использовать все тот же SVHN.

# %%
def prepare_for_linear_classifier(train_X, test_X):
    train_flat = train_X.reshape(train_X.shape[0], -1).astype(float) / 255.0
    test_flat = test_X.reshape(test_X.shape[0], -1).astype(float) / 255.0
    
    # Subtract mean
    mean_image = np.mean(train_flat, axis = 0)
    train_flat -= mean_image
    test_flat -= mean_image
    
    # Add another channel with ones as a bias term
    train_flat_with_ones = np.hstack([train_flat, np.ones((train_X.shape[0], 1))])
    test_flat_with_ones = np.hstack([test_flat, np.ones((test_X.shape[0], 1))])    
    return train_flat_with_ones, test_flat_with_ones
    
train_X, train_y, test_X, test_y = load_svhn("data", max_train=10000, max_test=1000)    
train_X, test_X = prepare_for_linear_classifier(train_X, test_X)
# Split train into train and val
train_X, train_y, val_X, val_y = random_split_train_val(train_X, train_y, num_val = 1000)

# %% [markdown]
# # Играемся с градиентами!
#
# В этом курсе мы будем писать много функций, которые вычисляют градиенты аналитическим методом.
#
# Все функции, в которых мы будем вычислять градиенты, будут написаны по одной и той же схеме.
# Они будут получать на вход точку, где нужно вычислить значение и градиент функции, а на выходе будут выдавать кортеж (tuple) из двух значений - собственно значения функции в этой точке (всегда одно число) и аналитического значения градиента в той же точке (той же размерности, что и вход).
# ```
# def f(x):
#     """
#     Computes function and analytic gradient at x
#
#     x: np array of float, input to the function
#
#     Returns:
#     value: float, value of the function
#     grad: np array of float, same shape as x
#     """
#     ...
#
#     return value, grad
# ```
#
# Необходимым инструментом во время реализации кода, вычисляющего градиенты, является функция его проверки. Эта функция вычисляет градиент численным методом и сверяет результат с градиентом, вычисленным аналитическим методом.
#
# Мы начнем с того, чтобы реализовать вычисление численного градиента (numeric gradient) в функции `check_gradient` в `gradient_check.py`. Эта функция будет принимать на вход функции формата, заданного выше, использовать значение `value` для вычисления численного градиента и сравнит его с аналитическим - они должны сходиться.
#
# Напишите часть функции, которая вычисляет градиент с помощью численной производной для каждой координаты. Для вычисления производной используйте так называемую two-point formula (https://en.wikipedia.org/wiki/Numerical_differentiation):
#
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/22fc2c0a66c63560a349604f8b6b39221566236d)
#
# Все функции приведенные в следующей клетке должны проходить gradient check.

# %%
# TODO: Implement check_gradient function in gradient_check.py
# All the functions below should pass the gradient check

def square(x):
    return float(x*x), 2*x

check_gradient(square, np.array([3.0]))

def array_sum(x):
    assert x.shape == (2,), x.shape
    return np.sum(x), np.ones_like(x)

check_gradient(array_sum, np.array([3.0, 2.0]))

def array_2d_sum(x):
    assert x.shape == (2,2)
    return np.sum(x), np.ones_like(x)

check_gradient(array_2d_sum, np.array([[3.0, 2.0], [1.0, 0.0]]))
# Out:
# Gradient check passed!
# Gradient check passed!
# Gradient check passed!
# True

# %% [markdown]
# ## Начинаем писать свои функции, считающие аналитический градиент
#
# Теперь реализуем функцию softmax, которая получает на вход оценки для каждого класса и преобразует их в вероятности от 0 до 1:
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/e348290cf48ddbb6e9a6ef4e39363568b67c09d3)
#
# **Важно:** Практический аспект вычисления этой функции заключается в том, что в ней учавствует вычисление экспоненты от потенциально очень больших чисел - это может привести к очень большим значениям в числителе и знаменателе за пределами диапазона float.
#
# К счастью, у этой проблемы есть простое решение -- перед вычислением softmax вычесть из всех оценок максимальное значение среди всех оценок:
# ```
# predictions -= np.max(predictions)
# ```
# (подробнее здесь - http://cs231n.github.io/linear-classify/#softmax, секция `Practical issues: Numeric stability`)

# %%
# TODO Implement softmax and cross-entropy for single sample
probs = linear_classifer.softmax(np.array([-10, 0, 10]))

# Make sure it works for big numbers too!
probs = linear_classifer.softmax(np.array([1000, 0, 0]))
assert np.isclose(probs[0], 1.0)

# %% [markdown]
# Кроме этого, мы реализуем cross-entropy loss, которую мы будем использовать как функцию ошибки (error function).
# В общем виде cross-entropy определена следующим образом:
# ![image](https://wikimedia.org/api/rest_v1/media/math/render/svg/0cb6da032ab424eefdca0884cd4113fe578f4293)
#
# где x - все классы, p(x) - истинная вероятность принадлежности сэмпла классу x, а q(x) - вероятность принадлежности классу x, предсказанная моделью.
# В нашем случае сэмпл принадлежит только одному классу, индекс которого передается функции. Для него p(x) равна 1, а для остальных классов - 0.
#
# Это позволяет реализовать функцию проще!

# %%
probs = linear_classifer.softmax(np.array([-5, 0, 5]))
linear_classifer.cross_entropy_loss(probs, 1)
# Out:
# 5.006760443547122

# %% [markdown]
# После того как мы реализовали сами функции, мы можем реализовать градиент.
#
# Оказывается, что вычисление градиента становится гораздо проще, если объединить эти функции в одну, которая сначала вычисляет вероятности через softmax, а потом использует их для вычисления функции ошибки через cross-entropy loss.
#
# Эта функция `softmax_with_cross_entropy` будет возвращает и значение ошибки, и градиент по входным параметрам. Мы проверим корректность реализации с помощью `check_gradient`.

# %%
# TODO Implement combined function or softmax and cross entropy and produces gradient
loss, grad = linear_classifer.softmax_with_cross_entropy(np.array([1, 0, 0]), 1)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, 1), np.array([1, 0, 0], float))
# Out:
# Gradient check passed!
# True

# %% [markdown]
# В качестве метода тренировки мы будем использовать стохастический градиентный спуск (stochastic gradient descent или SGD), который работает с батчами сэмплов.
#
# Поэтому все наши фукнции будут получать не один пример, а батч, то есть входом будет не вектор из `num_classes` оценок, а матрица размерности `batch_size, num_classes`. Индекс примера в батче всегда будет первым измерением.
#
# Следующий шаг - переписать наши функции так, чтобы они поддерживали батчи.
#
# Финальное значение функции ошибки должно остаться числом, и оно равно среднему значению ошибки среди всех примеров в батче.

# %%
# TODO Extend combined function so it can receive a 2d array with batch of samples
np.random.seed(42)
# Test batch_size = 1
num_classes = 4
batch_size = 1
predictions = np.random.randint(-1, 3, size=(batch_size, num_classes)).astype(float)
target_index = np.random.randint(0, num_classes, size=(batch_size, 1)).astype(int)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, target_index), predictions)

# Test batch_size = 3
num_classes = 4
batch_size = 3
predictions = np.random.randint(-1, 3, size=(batch_size, num_classes)).astype(float)
target_index = np.random.randint(0, num_classes, size=(batch_size, 1)).astype(int)
check_gradient(lambda x: linear_classifer.softmax_with_cross_entropy(x, target_index), predictions)

# Make sure maximum subtraction for numberic stability is done separately for every sample in the batch
probs = linear_classifer.softmax(np.array([[20,0,0], [1000, 0, 0]]))
assert np.all(np.isclose(probs[:, 0], 1.0))
# Out:
# Gradient check passed!
# Gradient check passed!

# %% [markdown]
# ### Наконец, реализуем сам линейный классификатор!
#
# softmax и cross-entropy получают на вход оценки, которые выдает линейный классификатор.
#
# Он делает это очень просто: для каждого класса есть набор весов, на которые надо умножить пиксели картинки и сложить. Получившееся число и является оценкой класса, идущей на вход softmax.
#
# Таким образом, линейный классификатор можно представить как умножение вектора с пикселями на матрицу W размера `num_features, num_classes`. Такой подход легко расширяется на случай батча векторов с пикселями X размера `batch_size, num_features`:
#
# `predictions = X * W`, где `*` - матричное умножение.
#
# Реализуйте функцию подсчета линейного классификатора и градиентов по весам `linear_softmax` в файле `linear_classifer.py`

# %%
# TODO Implement linear_softmax function that uses softmax with cross-entropy for linear classifier
batch_size = 2
num_classes = 2
num_features = 3
np.random.seed(42)
W = np.random.randint(-1, 3, size=(num_features, num_classes)).astype(float)
X = np.random.randint(-1, 3, size=(batch_size, num_features)).astype(float)
target_index = np.ones(batch_size, dtype=int)

loss, dW = linear_classifer.linear_softmax(X, W, target_index)
check_gradient(lambda w: linear_classifer.linear_softmax(X, w, target_index), W)
# Out:
# Gradient check passed!
# True

# %% [markdown]
# ### И теперь регуляризация
#
# Мы будем использовать L2 regularization для весов как часть общей функции ошибки.
#
# Напомним, L2 regularization определяется как
#
# l2_reg_loss = regularization_strength * sum<sub>ij</sub> W[i, j]<sup>2</sup>
#
# Реализуйте функцию для его вычисления и вычисления соотвествующих градиентов.

# %%
# TODO Implement l2_regularization function that implements loss for L2 regularization
linear_classifer.l2_regularization(W, 0.01)
check_gradient(lambda w: linear_classifer.l2_regularization(w, 0.01), W)
# Out:
# Gradient check passed!
# True

# %% [markdown]
# # Тренировка!

# %% [markdown]
# Градиенты в порядке, реализуем процесс тренировки!

# %%
# TODO: Implement LinearSoftmaxClassifier.fit function
classifier = linear_classifer.LinearSoftmaxClassifier()
loss_history = classifier.fit(train_X, train_y, epochs=10, learning_rate=1e-3, batch_size=300, reg=1e1)
# Out:
# Epoch 0, loss: 2.397363
# Epoch 1, loss: 2.330354
# Epoch 2, loss: 2.311002
# Epoch 3, loss: 2.303897
# Epoch 4, loss: 2.303257
# Epoch 5, loss: 2.302898
# Epoch 6, loss: 2.302564
# Epoch 7, loss: 2.301815
# Epoch 8, loss: 2.301252
# Epoch 9, loss: 2.301256

# %%
# let's look at the loss history!
plt.plot(loss_history)

# %%
# Let's check how it performs on validation set
pred = classifier.predict(val_X)
accuracy = multiclass_accuracy(pred, val_y)
print("Accuracy: ", accuracy)

# Now, let's train more and see if it performs better
classifier.fit(train_X, train_y, epochs=100, learning_rate=1e-3, batch_size=300, reg=1e1)
pred = classifier.predict(val_X)
accuracy = multiclass_accuracy(pred, val_y)
print("Accuracy after training for 100 epochs: ", accuracy)
# Out:
# Accuracy:  0.127
# Epoch 0, loss: 2.301800
# Epoch 1, loss: 2.302558
# Epoch 2, loss: 2.302208
# Epoch 3, loss: 2.303309
# Epoch 4, loss: 2.302126
# Epoch 5, loss: 2.301524
# Epoch 6, loss: 2.301150
# Epoch 7, loss: 2.301359
# Epoch 8, loss: 2.302305
# Epoch 9, loss: 2.302205
# Epoch 10, loss: 2.301595
# Epoch 11, loss: 2.302039
# Epoch 12, loss: 2.301247
# Epoch 13, loss: 2.301836
# Epoch 14, loss: 2.302396
# Epoch 15, loss: 2.302299
# Epoch 16, loss: 2.301161
# Epoch 17, loss: 2.302058
# Epoch 18, loss: 2.302180
# Epoch 19, loss: 2.302339
# Epoch 20, loss: 2.302694
# Epoch 21, loss: 2.301872
# Epoch 22, loss: 2.302261
# Epoch 23, loss: 2.302209
# Epoch 24, loss: 2.302215
# Epoch 25, loss: 2.301591
# Epoch 26, loss: 2.301535
# Epoch 27, loss: 2.302557
# Epoch 28, loss: 2.301689
# Epoch 29, loss: 2.301815
# Epoch 30, loss: 2.301483
# Epoch 31, loss: 2.301553
# Epoch 32, loss: 2.301640
# Epoch 33, loss: 2.301991
# Epoch 34, loss: 2.302104
# Epoch 35, loss: 2.301741
# Epoch 36, loss: 2.302652
# Epoch 37, loss: 2.303017
# Epoch 38, loss: 2.301521
# Epoch 39, loss: 2.301504
# Epoch 40, loss: 2.301565
# Epoch 41, loss: 2.302361
# Epoch 42, loss: 2.302223
# Epoch 43, loss: 2.302385
# Epoch 44, loss: 2.302532
# Epoch 45, loss: 2.301950
# Epoch 46, loss: 2.301686
# Epoch 47, loss: 2.301881
# Epoch 48, loss: 2.302291
# Epoch 49, loss: 2.302069
# Epoch 50, loss: 2.301971
# Epoch 51, loss: 2.302533
# Epoch 52, loss: 2.302043
# Epoch 53, loss: 2.302003
# Epoch 54, loss: 2.301729
# Epoch 55, loss: 2.301272
# Epoch 56, loss: 2.302220
# Epoch 57, loss: 2.301765
# Epoch 58, loss: 2.301959
# Epoch 59, loss: 2.302229
# Epoch 60, loss: 2.301372
# Epoch 61, loss: 2.302540
# Epoch 62, loss: 2.301929
# Epoch 63, loss: 2.301502
# Epoch 64, loss: 2.302201
# Epoch 65, loss: 2.302674
# Epoch 66, loss: 2.302191
# Epoch 67, loss: 2.302989
# Epoch 68, loss: 2.301388
# Epoch 69, loss: 2.301621
# Epoch 70, loss: 2.301533
# Epoch 71, loss: 2.302804
# Epoch 72, loss: 2.301514
# Epoch 73, loss: 2.300962
# Epoch 74, loss: 2.302366
# Epoch 75, loss: 2.301895
# Epoch 76, loss: 2.301768
# Epoch 77, loss: 2.302649
# Epoch 78, loss: 2.302394
# Epoch 79, loss: 2.301415
# Epoch 80, loss: 2.302148
# Epoch 81, loss: 2.302263
# Epoch 82, loss: 2.301172
# Epoch 83, loss: 2.302803
# Epoch 84, loss: 2.301892
# Epoch 85, loss: 2.302788
# Epoch 86, loss: 2.302016
# Epoch 87, loss: 2.302450
# Epoch 88, loss: 2.302002
# Epoch 89, loss: 2.302363
# Epoch 90, loss: 2.301257
# Epoch 91, loss: 2.302553
# Epoch 92, loss: 2.301951
# Epoch 93, loss: 2.300910
# Epoch 94, loss: 2.302318
# Epoch 95, loss: 2.301563
# Epoch 96, loss: 2.302494
# Epoch 97, loss: 2.301579
# Epoch 98, loss: 2.302468
# Epoch 99, loss: 2.302352
# Accuracy after training for 100 epochs:  0.121

# %% [markdown]
# ### Как и раньше, используем кросс-валидацию для подбора гиперпараметтов.
#
# В этот раз, чтобы тренировка занимала разумное время, мы будем использовать только одно разделение на тренировочные (training) и проверочные (validation) данные.
#
# Теперь нам нужно подобрать не один, а два гиперпараметра! Не ограничивайте себя изначальными значениями в коде.
# Добейтесь точности более чем **20%** на проверочных данных (validation data).

# %%
num_epochs = 200
batch_size = 300

learning_rates = [1e-3, 1e-4, 1e-5]
reg_strengths = [1e-4, 1e-5, 1e-6]

best_classifier = None
best_val_accuracy = 0

# TODO use validation set to find the best hyperparameters
# hint: for best results, you might need to try more values for learning rate and regularization strength 
# than provided initially
for lr in learning_rates:
    for rs in reg_strengths:
        classifier = linear_classifer.LinearSoftmaxClassifier()
        loss_history = classifier.fit(train_X, train_y, epochs=num_epochs,
                                      learning_rate=lr, batch_size=batch_size, reg=rs)
        pred = classifier.predict(val_X)
        accuracy = multiclass_accuracy(pred, val_y)
        if accuracy > best_val_accuracy:
            best_classifier = classifier
            best_val_accuracy = accuracy
            best_lr, best_rs = lr, rs
            
print('hyper-parameters: lr = {}, rs = {}'.format(lr, rs))
print('best validation accuracy achieved: %f' % best_val_accuracy)
# Out:
# Epoch 0, loss: 2.301470
# Epoch 1, loss: 2.300368
# Epoch 2, loss: 2.299128
# Epoch 3, loss: 2.299072
# Epoch 4, loss: 2.297444
# Epoch 5, loss: 2.295904
# Epoch 6, loss: 2.293397
# Epoch 7, loss: 2.296875
# Epoch 8, loss: 2.295133
# Epoch 9, loss: 2.292857
# Epoch 10, loss: 2.290978
# Epoch 11, loss: 2.291628
# Epoch 12, loss: 2.287297
# Epoch 13, loss: 2.292894
# Epoch 14, loss: 2.289672
# Epoch 15, loss: 2.286690
# Epoch 16, loss: 2.284671
# Epoch 17, loss: 2.287627
# Epoch 18, loss: 2.284447
# Epoch 19, loss: 2.287718
# Epoch 20, loss: 2.285870
# Epoch 21, loss: 2.278746
# Epoch 22, loss: 2.277522
# Epoch 23, loss: 2.284406
# Epoch 24, loss: 2.274678
# Epoch 25, loss: 2.276643
# Epoch 26, loss: 2.281626
# Epoch 27, loss: 2.272920
# Epoch 28, loss: 2.280301
# Epoch 29, loss: 2.277529
# Epoch 30, loss: 2.282802
# Epoch 31, loss: 2.273901
# Epoch 32, loss: 2.271925
# Epoch 33, loss: 2.276733
# Epoch 34, loss: 2.275226
# Epoch 35, loss: 2.284179
# Epoch 36, loss: 2.270381
# Epoch 37, loss: 2.278204
# Epoch 38, loss: 2.266460
# Epoch 39, loss: 2.273364
# Epoch 40, loss: 2.271086
# Epoch 41, loss: 2.265518
# Epoch 42, loss: 2.258758
# Epoch 43, loss: 2.283588
# Epoch 44, loss: 2.273291
# Epoch 45, loss: 2.259672
# Epoch 46, loss: 2.279102
# Epoch 47, loss: 2.270678
# Epoch 48, loss: 2.263032
# Epoch 49, loss: 2.256021
# Epoch 50, loss: 2.262982
# Epoch 51, loss: 2.266699
# Epoch 52, loss: 2.275339
# Epoch 53, loss: 2.264175
# Epoch 54, loss: 2.250636
# Epoch 55, loss: 2.275040
# Epoch 56, loss: 2.254126
# Epoch 57, loss: 2.260509
# Epoch 58, loss: 2.261265
# Epoch 59, loss: 2.269881
# Epoch 60, loss: 2.258866
# Epoch 61, loss: 2.260369
# Epoch 62, loss: 2.257949
# Epoch 63, loss: 2.249924
# Epoch 64, loss: 2.258558
# Epoch 65, loss: 2.236728
# Epoch 66, loss: 2.259154
# Epoch 67, loss: 2.247770
# Epoch 68, loss: 2.259372
# Epoch 69, loss: 2.251611
# Epoch 70, loss: 2.244562
# Epoch 71, loss: 2.249155
# Epoch 72, loss: 2.243457
# Epoch 73, loss: 2.245145
# Epoch 74, loss: 2.252727
# Epoch 75, loss: 2.240752
# Epoch 76, loss: 2.259297
# Epoch 77, loss: 2.258521
# Epoch 78, loss: 2.250610
# Epoch 79, loss: 2.226804
# Epoch 80, loss: 2.262575
# Epoch 81, loss: 2.255834
# Epoch 82, loss: 2.237241
# Epoch 83, loss: 2.259402
# Epoch 84, loss: 2.263056
# Epoch 85, loss: 2.242471
# Epoch 86, loss: 2.233570
# Epoch 87, loss: 2.244740
# Epoch 88, loss: 2.237856
# Epoch 89, loss: 2.250038
# Epoch 90, loss: 2.247331
# Epoch 91, loss: 2.242694
# Epoch 92, loss: 2.243468
# Epoch 93, loss: 2.235224
# Epoch 94, loss: 2.245227
# Epoch 95, loss: 2.252012
# Epoch 96, loss: 2.238705
# Epoch 97, loss: 2.247506
# Epoch 98, loss: 2.253196
# Epoch 99, loss: 2.233897
# Epoch 100, loss: 2.232111
# Epoch 101, loss: 2.246976
# Epoch 102, loss: 2.239813
# Epoch 103, loss: 2.240623
# Epoch 104, loss: 2.241474
# Epoch 105, loss: 2.231639
# Epoch 106, loss: 2.232258
# Epoch 107, loss: 2.222580
# Epoch 108, loss: 2.222023
# Epoch 109, loss: 2.222909
# Epoch 110, loss: 2.229863
# Epoch 111, loss: 2.246397
# Epoch 112, loss: 2.223380
# Epoch 113, loss: 2.245725
# Epoch 114, loss: 2.235658
# Epoch 115, loss: 2.228080
# Epoch 116, loss: 2.231045
# Epoch 117, loss: 2.232467
# Epoch 118, loss: 2.230641
# Epoch 119, loss: 2.243804
# Epoch 120, loss: 2.218011
# Epoch 121, loss: 2.214711
# Epoch 122, loss: 2.225225
# Epoch 123, loss: 2.229207
# Epoch 124, loss: 2.222635
# Epoch 125, loss: 2.234345
# Epoch 126, loss: 2.222915
# Epoch 127, loss: 2.230427
# Epoch 128, loss: 2.216729
# Epoch 129, loss: 2.229302
# Epoch 130, loss: 2.225581
# Epoch 131, loss: 2.227056
# Epoch 132, loss: 2.228452
# Epoch 133, loss: 2.223855
# Epoch 134, loss: 2.219900
# Epoch 135, loss: 2.217743
# Epoch 136, loss: 2.223540
# Epoch 137, loss: 2.206583
# Epoch 138, loss: 2.216051
# Epoch 139, loss: 2.224065
# Epoch 140, loss: 2.203614
# Epoch 141, loss: 2.216364
# Epoch 142, loss: 2.204713
# Epoch 143, loss: 2.224866
# Epoch 144, loss: 2.210761
# Epoch 145, loss: 2.225902
# Epoch 146, loss: 2.220528
# Epoch 147, loss: 2.226958
# Epoch 148, loss: 2.204381
# Epoch 149, loss: 2.236246
# Epoch 150, loss: 2.234451
# Epoch 151, loss: 2.231626
# Epoch 152, loss: 2.213127
# Epoch 153, loss: 2.223110
# Epoch 154, loss: 2.222077
# Epoch 155, loss: 2.222900
# Epoch 156, loss: 2.216451
# Epoch 157, loss: 2.206286
# Epoch 158, loss: 2.213973
# Epoch 159, loss: 2.212270
# Epoch 160, loss: 2.211806
# Epoch 161, loss: 2.206103
# Epoch 162, loss: 2.228196
# Epoch 163, loss: 2.212204
# Epoch 164, loss: 2.242993
# Epoch 165, loss: 2.215876
# Epoch 166, loss: 2.191993
# Epoch 167, loss: 2.233465
# Epoch 168, loss: 2.192981
# Epoch 169, loss: 2.196137
# Epoch 170, loss: 2.190295
# Epoch 171, loss: 2.204775
# Epoch 172, loss: 2.200142
# Epoch 173, loss: 2.192747
# Epoch 174, loss: 2.217394
# Epoch 175, loss: 2.226258
# Epoch 176, loss: 2.190525
# Epoch 177, loss: 2.209792
# Epoch 178, loss: 2.201152
# Epoch 179, loss: 2.197789
# Epoch 180, loss: 2.197007
# Epoch 181, loss: 2.219098
# Epoch 182, loss: 2.191991
# Epoch 183, loss: 2.210316
# Epoch 184, loss: 2.224227
# Epoch 185, loss: 2.196247
# Epoch 186, loss: 2.205351
# Epoch 187, loss: 2.196606
# Epoch 188, loss: 2.177732
# Epoch 189, loss: 2.206341
# Epoch 190, loss: 2.214563
# Epoch 191, loss: 2.235417
# Epoch 192, loss: 2.200704
# Epoch 193, loss: 2.197991
# Epoch 194, loss: 2.232236
# Epoch 195, loss: 2.197152
# Epoch 196, loss: 2.201354
# Epoch 197, loss: 2.214352
# Epoch 198, loss: 2.185849
# Epoch 199, loss: 2.208514
# Epoch 0, loss: 2.301687
# Epoch 1, loss: 2.301628
# Epoch 2, loss: 2.301045
# Epoch 3, loss: 2.300703
# Epoch 4, loss: 2.297666
# Epoch 5, loss: 2.296545
# Epoch 6, loss: 2.296853
# Epoch 7, loss: 2.295111
# Epoch 8, loss: 2.292554
# Epoch 9, loss: 2.292229
# Epoch 10, loss: 2.294168
# Epoch 11, loss: 2.292064
# Epoch 12, loss: 2.294367
# Epoch 13, loss: 2.290998
# Epoch 14, loss: 2.291396
# Epoch 15, loss: 2.288173
# Epoch 16, loss: 2.285320
# Epoch 17, loss: 2.285359
# Epoch 18, loss: 2.288876
# Epoch 19, loss: 2.286446
# Epoch 20, loss: 2.285717
# Epoch 21, loss: 2.288272
# Epoch 22, loss: 2.286048
# Epoch 23, loss: 2.277585
# Epoch 24, loss: 2.280337
# Epoch 25, loss: 2.285482
# Epoch 26, loss: 2.277464
# Epoch 27, loss: 2.270902
# Epoch 28, loss: 2.288928
# Epoch 29, loss: 2.280812
# Epoch 30, loss: 2.281646
# Epoch 31, loss: 2.275744
# Epoch 32, loss: 2.283931
# Epoch 33, loss: 2.276758
# Epoch 34, loss: 2.275387
# Epoch 35, loss: 2.275649
# Epoch 36, loss: 2.271613
# Epoch 37, loss: 2.276327
# Epoch 38, loss: 2.267750
# Epoch 39, loss: 2.267790
# Epoch 40, loss: 2.266784
# Epoch 41, loss: 2.269618
# Epoch 42, loss: 2.261778
# Epoch 43, loss: 2.266245
# Epoch 44, loss: 2.263289
# Epoch 45, loss: 2.257646
# Epoch 46, loss: 2.268251
# Epoch 47, loss: 2.264001
# Epoch 48, loss: 2.267222
# Epoch 49, loss: 2.266106
# Epoch 50, loss: 2.255233
# Epoch 51, loss: 2.268990
# Epoch 52, loss: 2.258561
# Epoch 53, loss: 2.266103
# Epoch 54, loss: 2.270402
# Epoch 55, loss: 2.262911
# Epoch 56, loss: 2.267208
# Epoch 57, loss: 2.260639
# Epoch 58, loss: 2.253339
# Epoch 59, loss: 2.258912
# Epoch 60, loss: 2.261036
# Epoch 61, loss: 2.250495
# Epoch 62, loss: 2.251896
# Epoch 63, loss: 2.261195
# Epoch 64, loss: 2.264427
# Epoch 65, loss: 2.243846
# Epoch 66, loss: 2.249728
# Epoch 67, loss: 2.249388
# Epoch 68, loss: 2.250772
# Epoch 69, loss: 2.254091
# Epoch 70, loss: 2.254414
# Epoch 71, loss: 2.253679
# Epoch 72, loss: 2.254627
# Epoch 73, loss: 2.248443
# Epoch 74, loss: 2.252926
# Epoch 75, loss: 2.246762
# Epoch 76, loss: 2.259919
# Epoch 77, loss: 2.244611
# Epoch 78, loss: 2.252328
# Epoch 79, loss: 2.258683
# Epoch 80, loss: 2.241656
# Epoch 81, loss: 2.239845
# Epoch 82, loss: 2.246258
# Epoch 83, loss: 2.257298
# Epoch 84, loss: 2.238734
# Epoch 85, loss: 2.244705
# Epoch 86, loss: 2.252053
# Epoch 87, loss: 2.254031
# Epoch 88, loss: 2.232890
# Epoch 89, loss: 2.236922
# Epoch 90, loss: 2.247616
# Epoch 91, loss: 2.255523
# Epoch 92, loss: 2.251865
# Epoch 93, loss: 2.233272
# Epoch 94, loss: 2.270267
# Epoch 95, loss: 2.235828
# Epoch 96, loss: 2.228099
# Epoch 97, loss: 2.234393
# Epoch 98, loss: 2.232913
# Epoch 99, loss: 2.249431
# Epoch 100, loss: 2.232280
# Epoch 101, loss: 2.225687
# Epoch 102, loss: 2.235520
# Epoch 103, loss: 2.227709
# Epoch 104, loss: 2.232148
# Epoch 105, loss: 2.255264
# Epoch 106, loss: 2.228918
# Epoch 107, loss: 2.224202
# Epoch 108, loss: 2.238809
# Epoch 109, loss: 2.241293
# Epoch 110, loss: 2.234178
# Epoch 111, loss: 2.229373
# Epoch 112, loss: 2.247207
# Epoch 113, loss: 2.235918
# Epoch 114, loss: 2.233654
# Epoch 115, loss: 2.244250
# Epoch 116, loss: 2.213234
# Epoch 117, loss: 2.226305
# Epoch 118, loss: 2.233921
# Epoch 119, loss: 2.234220
# Epoch 120, loss: 2.242608
# Epoch 121, loss: 2.217887
# Epoch 122, loss: 2.219815
# Epoch 123, loss: 2.232064
# Epoch 124, loss: 2.238724
# Epoch 125, loss: 2.239627
# Epoch 126, loss: 2.229895
# Epoch 127, loss: 2.217815
# Epoch 128, loss: 2.219549
# Epoch 129, loss: 2.215667
# Epoch 130, loss: 2.237329
# Epoch 131, loss: 2.197713
# Epoch 132, loss: 2.216853
# Epoch 133, loss: 2.253070
# Epoch 134, loss: 2.219512
# Epoch 135, loss: 2.220860
# Epoch 136, loss: 2.237236
# Epoch 137, loss: 2.220003
# Epoch 138, loss: 2.230873
# Epoch 139, loss: 2.219746
# Epoch 140, loss: 2.249013
# Epoch 141, loss: 2.232336
# Epoch 142, loss: 2.224393
# Epoch 143, loss: 2.201155
# Epoch 144, loss: 2.225371
# Epoch 145, loss: 2.196251
# Epoch 146, loss: 2.229903
# Epoch 147, loss: 2.210638
# Epoch 148, loss: 2.222474
# Epoch 149, loss: 2.215643
# Epoch 150, loss: 2.199676
# Epoch 151, loss: 2.240989
# Epoch 152, loss: 2.233873
# Epoch 153, loss: 2.219734
# Epoch 154, loss: 2.208523
# Epoch 155, loss: 2.191390
# Epoch 156, loss: 2.211645
# Epoch 157, loss: 2.198004
# Epoch 158, loss: 2.206878
# Epoch 159, loss: 2.236927
# Epoch 160, loss: 2.197007
# Epoch 161, loss: 2.228392
# Epoch 162, loss: 2.222051
# Epoch 163, loss: 2.183594
# Epoch 164, loss: 2.213957
# Epoch 165, loss: 2.233669
# Epoch 166, loss: 2.214902
# Epoch 167, loss: 2.209697
# Epoch 168, loss: 2.180105
# Epoch 169, loss: 2.224433
# Epoch 170, loss: 2.202232
# Epoch 171, loss: 2.194884
# Epoch 172, loss: 2.193687
# Epoch 173, loss: 2.216549
# Epoch 174, loss: 2.204423
# Epoch 175, loss: 2.236042
# Epoch 176, loss: 2.198239
# Epoch 177, loss: 2.213583
# Epoch 178, loss: 2.207943
# Epoch 179, loss: 2.218068
# Epoch 180, loss: 2.198313
# Epoch 181, loss: 2.216382
# Epoch 182, loss: 2.194448
# Epoch 183, loss: 2.215963
# Epoch 184, loss: 2.211250
# Epoch 185, loss: 2.215132
# Epoch 186, loss: 2.227181
# Epoch 187, loss: 2.200421
# Epoch 188, loss: 2.205717
# Epoch 189, loss: 2.230391
# Epoch 190, loss: 2.210872
# Epoch 191, loss: 2.210912
# Epoch 192, loss: 2.214310
# Epoch 193, loss: 2.204172
# Epoch 194, loss: 2.218367
# Epoch 195, loss: 2.203412
# Epoch 196, loss: 2.216023
# Epoch 197, loss: 2.193382
# Epoch 198, loss: 2.183870
# Epoch 199, loss: 2.189203
# Epoch 0, loss: 2.302679
# Epoch 1, loss: 2.301634
# Epoch 2, loss: 2.299515
# Epoch 3, loss: 2.298675
# Epoch 4, loss: 2.295077
# Epoch 5, loss: 2.296998
# Epoch 6, loss: 2.295991
# Epoch 7, loss: 2.293064
# Epoch 8, loss: 2.296119
# Epoch 9, loss: 2.294548
# Epoch 10, loss: 2.293317
# Epoch 11, loss: 2.296240
# Epoch 12, loss: 2.287652
# Epoch 13, loss: 2.291447
# Epoch 14, loss: 2.291231
# Epoch 15, loss: 2.288898
# Epoch 16, loss: 2.289836
# Epoch 17, loss: 2.285886
# Epoch 18, loss: 2.285361
# Epoch 19, loss: 2.280396
# Epoch 20, loss: 2.286984
# Epoch 21, loss: 2.280727
# Epoch 22, loss: 2.278272
# Epoch 23, loss: 2.282625
# Epoch 24, loss: 2.281065
# Epoch 25, loss: 2.282900
# Epoch 26, loss: 2.282514
# Epoch 27, loss: 2.286021
# Epoch 28, loss: 2.285498
# Epoch 29, loss: 2.280335
# Epoch 30, loss: 2.276562
# Epoch 31, loss: 2.282397
# Epoch 32, loss: 2.274032
# Epoch 33, loss: 2.270709
# Epoch 34, loss: 2.282459
# Epoch 35, loss: 2.278292
# Epoch 36, loss: 2.276911
# Epoch 37, loss: 2.277015
# Epoch 38, loss: 2.285369
# Epoch 39, loss: 2.269282
# Epoch 40, loss: 2.271423
# Epoch 41, loss: 2.266593
# Epoch 42, loss: 2.257924
# Epoch 43, loss: 2.262167
# Epoch 44, loss: 2.263394
# Epoch 45, loss: 2.265818
# Epoch 46, loss: 2.269000
# Epoch 47, loss: 2.260290
# Epoch 48, loss: 2.271691
# Epoch 49, loss: 2.264026
# Epoch 50, loss: 2.256934
# Epoch 51, loss: 2.265453
# Epoch 52, loss: 2.260881
# Epoch 53, loss: 2.282915
# Epoch 54, loss: 2.246235
# Epoch 55, loss: 2.255664
# Epoch 56, loss: 2.270773
# Epoch 57, loss: 2.243764
# Epoch 58, loss: 2.253537
# Epoch 59, loss: 2.249935
# Epoch 60, loss: 2.264457
# Epoch 61, loss: 2.256122
# Epoch 62, loss: 2.260139
# Epoch 63, loss: 2.266273
# Epoch 64, loss: 2.238654
# Epoch 65, loss: 2.252155
# Epoch 66, loss: 2.239193
# Epoch 67, loss: 2.254845
# Epoch 68, loss: 2.240417
# Epoch 69, loss: 2.267783
# Epoch 70, loss: 2.244224
# Epoch 71, loss: 2.252267
# Epoch 72, loss: 2.248065
# Epoch 73, loss: 2.255025
# Epoch 74, loss: 2.256683
# Epoch 75, loss: 2.260620
# Epoch 76, loss: 2.229696
# Epoch 77, loss: 2.242649
# Epoch 78, loss: 2.257661
# Epoch 79, loss: 2.244393
# Epoch 80, loss: 2.246446
# Epoch 81, loss: 2.231723
# Epoch 82, loss: 2.240739
# Epoch 83, loss: 2.238388
# Epoch 84, loss: 2.253074
# Epoch 85, loss: 2.235932
# Epoch 86, loss: 2.227343
# Epoch 87, loss: 2.258804
# Epoch 88, loss: 2.248805
# Epoch 89, loss: 2.240521
# Epoch 90, loss: 2.238833
# Epoch 91, loss: 2.241798
# Epoch 92, loss: 2.258982
# Epoch 93, loss: 2.236740
# Epoch 94, loss: 2.224550
# Epoch 95, loss: 2.261222
# Epoch 96, loss: 2.243694
# Epoch 97, loss: 2.251232
# Epoch 98, loss: 2.221366
# Epoch 99, loss: 2.230438
# Epoch 100, loss: 2.247320
# Epoch 101, loss: 2.230473
# Epoch 102, loss: 2.255670
# Epoch 103, loss: 2.234066
# Epoch 104, loss: 2.243823
# Epoch 105, loss: 2.231388
# Epoch 106, loss: 2.229017
# Epoch 107, loss: 2.210577
# Epoch 108, loss: 2.251847
# Epoch 109, loss: 2.235340
# Epoch 110, loss: 2.237245
# Epoch 111, loss: 2.229230
# Epoch 112, loss: 2.244166
# Epoch 113, loss: 2.228457
# Epoch 114, loss: 2.223962
# Epoch 115, loss: 2.227825
# Epoch 116, loss: 2.236451
# Epoch 117, loss: 2.236556
# Epoch 118, loss: 2.232535
# Epoch 119, loss: 2.240898
# Epoch 120, loss: 2.226814
# Epoch 121, loss: 2.223321
# Epoch 122, loss: 2.223950
# Epoch 123, loss: 2.234283
# Epoch 124, loss: 2.229033
# Epoch 125, loss: 2.209954
# Epoch 126, loss: 2.224646
# Epoch 127, loss: 2.233392
# Epoch 128, loss: 2.233995
# Epoch 129, loss: 2.214923
# Epoch 130, loss: 2.239474
# Epoch 131, loss: 2.220474
# Epoch 132, loss: 2.215780
# Epoch 133, loss: 2.235357
# Epoch 134, loss: 2.230963
# Epoch 135, loss: 2.230612
# Epoch 136, loss: 2.202220
# Epoch 137, loss: 2.222375
# Epoch 138, loss: 2.215476
# Epoch 139, loss: 2.206316
# Epoch 140, loss: 2.197896
# Epoch 141, loss: 2.226401
# Epoch 142, loss: 2.191587
# Epoch 143, loss: 2.229695
# Epoch 144, loss: 2.220979
# Epoch 145, loss: 2.218095
# Epoch 146, loss: 2.223798
# Epoch 147, loss: 2.215108
# Epoch 148, loss: 2.221494
# Epoch 149, loss: 2.220641
# Epoch 150, loss: 2.214217
# Epoch 151, loss: 2.213989
# Epoch 152, loss: 2.208687
# Epoch 153, loss: 2.207808
# Epoch 154, loss: 2.205875
# Epoch 155, loss: 2.226845
# Epoch 156, loss: 2.219605
# Epoch 157, loss: 2.194259
# Epoch 158, loss: 2.231835
# Epoch 159, loss: 2.206490
# Epoch 160, loss: 2.206041
# Epoch 161, loss: 2.241054
# Epoch 162, loss: 2.204727
# Epoch 163, loss: 2.201773
# Epoch 164, loss: 2.185573
# Epoch 165, loss: 2.185633
# Epoch 166, loss: 2.185841
# Epoch 167, loss: 2.226598
# Epoch 168, loss: 2.206578
# Epoch 169, loss: 2.213364
# Epoch 170, loss: 2.222688
# Epoch 171, loss: 2.236274
# Epoch 172, loss: 2.221087
# Epoch 173, loss: 2.203297
# Epoch 174, loss: 2.209534
# Epoch 175, loss: 2.182567
# Epoch 176, loss: 2.227262
# Epoch 177, loss: 2.225811
# Epoch 178, loss: 2.201231
# Epoch 179, loss: 2.197498
# Epoch 180, loss: 2.218410
# Epoch 181, loss: 2.199325
# Epoch 182, loss: 2.201930
# Epoch 183, loss: 2.200315
# Epoch 184, loss: 2.200720
# Epoch 185, loss: 2.231531
# Epoch 186, loss: 2.214351
# Epoch 187, loss: 2.209649
# Epoch 188, loss: 2.220985
# Epoch 189, loss: 2.198961
# Epoch 190, loss: 2.195250
# Epoch 191, loss: 2.219765
# Epoch 192, loss: 2.187587
# Epoch 193, loss: 2.182481
# Epoch 194, loss: 2.188326
# Epoch 195, loss: 2.192377
# Epoch 196, loss: 2.207652
# Epoch 197, loss: 2.222877
# Epoch 198, loss: 2.175014
# Epoch 199, loss: 2.199606
# Epoch 0, loss: 2.302050
# Epoch 1, loss: 2.301530
# Epoch 2, loss: 2.302313
# Epoch 3, loss: 2.302560
# Epoch 4, loss: 2.302755
# Epoch 5, loss: 2.300913
# Epoch 6, loss: 2.301426
# Epoch 7, loss: 2.301148
# Epoch 8, loss: 2.301841
# Epoch 9, loss: 2.301559
# Epoch 10, loss: 2.300739
# Epoch 11, loss: 2.301813
# Epoch 12, loss: 2.300810
# Epoch 13, loss: 2.300204
# Epoch 14, loss: 2.300989
# Epoch 15, loss: 2.299985
# Epoch 16, loss: 2.300575
# Epoch 17, loss: 2.299773
# Epoch 18, loss: 2.301216
# Epoch 19, loss: 2.300987
# Epoch 20, loss: 2.300263
# Epoch 21, loss: 2.301209
# Epoch 22, loss: 2.299324
# Epoch 23, loss: 2.300718
# Epoch 24, loss: 2.300295
# Epoch 25, loss: 2.301049
# Epoch 26, loss: 2.298908
# Epoch 27, loss: 2.300954
# Epoch 28, loss: 2.298941
# Epoch 29, loss: 2.299598
# Epoch 30, loss: 2.300462
# Epoch 31, loss: 2.298216
# Epoch 32, loss: 2.300506
# Epoch 33, loss: 2.299735
# Epoch 34, loss: 2.296332
# Epoch 35, loss: 2.298282
# Epoch 36, loss: 2.299811
# Epoch 37, loss: 2.299675
# Epoch 38, loss: 2.298289
# Epoch 39, loss: 2.297994
# Epoch 40, loss: 2.296358
# Epoch 41, loss: 2.296974
# Epoch 42, loss: 2.299287
# Epoch 43, loss: 2.298892
# Epoch 44, loss: 2.295393
# Epoch 45, loss: 2.300725
# Epoch 46, loss: 2.297788
# Epoch 47, loss: 2.298475
# Epoch 48, loss: 2.295169
# Epoch 49, loss: 2.298482
# Epoch 50, loss: 2.299064
# Epoch 51, loss: 2.297588
# Epoch 52, loss: 2.296361
# Epoch 53, loss: 2.298292
# Epoch 54, loss: 2.295490
# Epoch 55, loss: 2.295345
# Epoch 56, loss: 2.295824
# Epoch 57, loss: 2.295864
# Epoch 58, loss: 2.296035
# Epoch 59, loss: 2.298090
# Epoch 60, loss: 2.296123
# Epoch 61, loss: 2.294478
# Epoch 62, loss: 2.295385
# Epoch 63, loss: 2.295805
# Epoch 64, loss: 2.295556
# Epoch 65, loss: 2.297864
# Epoch 66, loss: 2.299262
# Epoch 67, loss: 2.296031
# Epoch 68, loss: 2.294514
# Epoch 69, loss: 2.293063
# Epoch 70, loss: 2.296823
# Epoch 71, loss: 2.294473
# Epoch 72, loss: 2.296258
# Epoch 73, loss: 2.297881
# Epoch 74, loss: 2.294027
# Epoch 75, loss: 2.294728
# Epoch 76, loss: 2.297233
# Epoch 77, loss: 2.294478
# Epoch 78, loss: 2.296655
# Epoch 79, loss: 2.296177
# Epoch 80, loss: 2.297156
# Epoch 81, loss: 2.296660
# Epoch 82, loss: 2.295186
# Epoch 83, loss: 2.296778
# Epoch 84, loss: 2.296160
# Epoch 85, loss: 2.292791
# Epoch 86, loss: 2.293871
# Epoch 87, loss: 2.294790
# Epoch 88, loss: 2.291119
# Epoch 89, loss: 2.289559
# Epoch 90, loss: 2.292620
# Epoch 91, loss: 2.296037
# Epoch 92, loss: 2.291064
# Epoch 93, loss: 2.292354
# Epoch 94, loss: 2.291757
# Epoch 95, loss: 2.293071
# Epoch 96, loss: 2.292344
# Epoch 97, loss: 2.295513
# Epoch 98, loss: 2.294713
# Epoch 99, loss: 2.292181
# Epoch 100, loss: 2.289221
# Epoch 101, loss: 2.290529
# Epoch 102, loss: 2.291023
# Epoch 103, loss: 2.292847
# Epoch 104, loss: 2.293358
# Epoch 105, loss: 2.289644
# Epoch 106, loss: 2.292639
# Epoch 107, loss: 2.292493
# Epoch 108, loss: 2.297757
# Epoch 109, loss: 2.287707
# Epoch 110, loss: 2.296885
# Epoch 111, loss: 2.293215
# Epoch 112, loss: 2.293266
# Epoch 113, loss: 2.295633
# Epoch 114, loss: 2.291112
# Epoch 115, loss: 2.291933
# Epoch 116, loss: 2.290691
# Epoch 117, loss: 2.291600
# Epoch 118, loss: 2.289825
# Epoch 119, loss: 2.289169
# Epoch 120, loss: 2.292675
# Epoch 121, loss: 2.295972
# Epoch 122, loss: 2.289758
# Epoch 123, loss: 2.295252
# Epoch 124, loss: 2.286936
# Epoch 125, loss: 2.291981
# Epoch 126, loss: 2.291297
# Epoch 127, loss: 2.295939
# Epoch 128, loss: 2.289394
# Epoch 129, loss: 2.289181
# Epoch 130, loss: 2.292436
# Epoch 131, loss: 2.291030
# Epoch 132, loss: 2.287393
# Epoch 133, loss: 2.289080
# Epoch 134, loss: 2.288228
# Epoch 135, loss: 2.290319
# Epoch 136, loss: 2.290347
# Epoch 137, loss: 2.293599
# Epoch 138, loss: 2.288637
# Epoch 139, loss: 2.285849
# Epoch 140, loss: 2.287221
# Epoch 141, loss: 2.290080
# Epoch 142, loss: 2.290293
# Epoch 143, loss: 2.290400
# Epoch 144, loss: 2.284651
# Epoch 145, loss: 2.287768
# Epoch 146, loss: 2.290522
# Epoch 147, loss: 2.288525
# Epoch 148, loss: 2.293494
# Epoch 149, loss: 2.286427
# Epoch 150, loss: 2.292639
# Epoch 151, loss: 2.292550
# Epoch 152, loss: 2.287671
# Epoch 153, loss: 2.288639
# Epoch 154, loss: 2.287979
# Epoch 155, loss: 2.283762
# Epoch 156, loss: 2.286778
# Epoch 157, loss: 2.289209
# Epoch 158, loss: 2.287007
# Epoch 159, loss: 2.290343
# Epoch 160, loss: 2.285928
# Epoch 161, loss: 2.290364
# Epoch 162, loss: 2.288217
# Epoch 163, loss: 2.288426
# Epoch 164, loss: 2.289095
# Epoch 165, loss: 2.291544
# Epoch 166, loss: 2.284761
# Epoch 167, loss: 2.286839
# Epoch 168, loss: 2.284372
# Epoch 169, loss: 2.294624
# Epoch 170, loss: 2.292300
# Epoch 171, loss: 2.284132
# Epoch 172, loss: 2.285909
# Epoch 173, loss: 2.288936
# Epoch 174, loss: 2.286553
# Epoch 175, loss: 2.286273
# Epoch 176, loss: 2.288134
# Epoch 177, loss: 2.290686
# Epoch 178, loss: 2.287304
# Epoch 179, loss: 2.294035
# Epoch 180, loss: 2.284823
# Epoch 181, loss: 2.287393
# Epoch 182, loss: 2.288460
# Epoch 183, loss: 2.288085
# Epoch 184, loss: 2.293197
# Epoch 185, loss: 2.282978
# Epoch 186, loss: 2.291688
# Epoch 187, loss: 2.286169
# Epoch 188, loss: 2.287347
# Epoch 189, loss: 2.285317
# Epoch 190, loss: 2.288839
# Epoch 191, loss: 2.282169
# Epoch 192, loss: 2.287010
# Epoch 193, loss: 2.287095
# Epoch 194, loss: 2.286635
# Epoch 195, loss: 2.286922
# Epoch 196, loss: 2.285320
# Epoch 197, loss: 2.286744
# Epoch 198, loss: 2.282881
# Epoch 199, loss: 2.283750
# Epoch 0, loss: 2.302613
# Epoch 1, loss: 2.301504
# Epoch 2, loss: 2.301688
# Epoch 3, loss: 2.301917
# Epoch 4, loss: 2.302143
# Epoch 5, loss: 2.302320
# Epoch 6, loss: 2.301554
# Epoch 7, loss: 2.302325
# Epoch 8, loss: 2.302196
# Epoch 9, loss: 2.301666
# Epoch 10, loss: 2.300379
# Epoch 11, loss: 2.302355
# Epoch 12, loss: 2.300258
# Epoch 13, loss: 2.300519
# Epoch 14, loss: 2.300403
# Epoch 15, loss: 2.300653
# Epoch 16, loss: 2.301641
# Epoch 17, loss: 2.299714
# Epoch 18, loss: 2.300935
# Epoch 19, loss: 2.301049
# Epoch 20, loss: 2.301535
# Epoch 21, loss: 2.299658
# Epoch 22, loss: 2.301058
# Epoch 23, loss: 2.300957
# Epoch 24, loss: 2.300075
# Epoch 25, loss: 2.299555
# Epoch 26, loss: 2.301325
# Epoch 27, loss: 2.299779
# Epoch 28, loss: 2.301423
# Epoch 29, loss: 2.299512
# Epoch 30, loss: 2.300058
# Epoch 31, loss: 2.299589
# Epoch 32, loss: 2.299471
# Epoch 33, loss: 2.298431
# Epoch 34, loss: 2.298536
# Epoch 35, loss: 2.299563
# Epoch 36, loss: 2.303322
# Epoch 37, loss: 2.297288
# Epoch 38, loss: 2.299603
# Epoch 39, loss: 2.298331
# Epoch 40, loss: 2.296332
# Epoch 41, loss: 2.301094
# Epoch 42, loss: 2.300036
# Epoch 43, loss: 2.297841
# Epoch 44, loss: 2.296747
# Epoch 45, loss: 2.298139
# Epoch 46, loss: 2.297538
# Epoch 47, loss: 2.295607
# Epoch 48, loss: 2.299108
# Epoch 49, loss: 2.298753
# Epoch 50, loss: 2.297703
# Epoch 51, loss: 2.297244
# Epoch 52, loss: 2.296588
# Epoch 53, loss: 2.300766
# Epoch 54, loss: 2.299168
# Epoch 55, loss: 2.295919
# Epoch 56, loss: 2.296549
# Epoch 57, loss: 2.295163
# Epoch 58, loss: 2.297897
# Epoch 59, loss: 2.297798
# Epoch 60, loss: 2.297180
# Epoch 61, loss: 2.296620
# Epoch 62, loss: 2.295002
# Epoch 63, loss: 2.295680
# Epoch 64, loss: 2.294383
# Epoch 65, loss: 2.297206
# Epoch 66, loss: 2.297033
# Epoch 67, loss: 2.294979
# Epoch 68, loss: 2.295914
# Epoch 69, loss: 2.296623
# Epoch 70, loss: 2.291989
# Epoch 71, loss: 2.297574
# Epoch 72, loss: 2.296168
# Epoch 73, loss: 2.297271
# Epoch 74, loss: 2.300188
# Epoch 75, loss: 2.300051
# Epoch 76, loss: 2.296118
# Epoch 77, loss: 2.299989
# Epoch 78, loss: 2.297315
# Epoch 79, loss: 2.293017
# Epoch 80, loss: 2.293451
# Epoch 81, loss: 2.293762
# Epoch 82, loss: 2.290304
# Epoch 83, loss: 2.294939
# Epoch 84, loss: 2.296418
# Epoch 85, loss: 2.292522
# Epoch 86, loss: 2.293366
# Epoch 87, loss: 2.294433
# Epoch 88, loss: 2.294855
# Epoch 89, loss: 2.290695
# Epoch 90, loss: 2.294553
# Epoch 91, loss: 2.294933
# Epoch 92, loss: 2.296881
# Epoch 93, loss: 2.293740
# Epoch 94, loss: 2.295456
# Epoch 95, loss: 2.290400
# Epoch 96, loss: 2.296767
# Epoch 97, loss: 2.290172
# Epoch 98, loss: 2.294657
# Epoch 99, loss: 2.295711
# Epoch 100, loss: 2.291592
# Epoch 101, loss: 2.292186
# Epoch 102, loss: 2.291193
# Epoch 103, loss: 2.294902
# Epoch 104, loss: 2.292930
# Epoch 105, loss: 2.294250
# Epoch 106, loss: 2.291185
# Epoch 107, loss: 2.292281
# Epoch 108, loss: 2.291512
# Epoch 109, loss: 2.294143
# Epoch 110, loss: 2.295299
# Epoch 111, loss: 2.296181
# Epoch 112, loss: 2.292644
# Epoch 113, loss: 2.291112
# Epoch 114, loss: 2.295030
# Epoch 115, loss: 2.292601
# Epoch 116, loss: 2.287182
# Epoch 117, loss: 2.289263
# Epoch 118, loss: 2.290435
# Epoch 119, loss: 2.292978
# Epoch 120, loss: 2.291483
# Epoch 121, loss: 2.290576
# Epoch 122, loss: 2.293482
# Epoch 123, loss: 2.295702
# Epoch 124, loss: 2.289008
# Epoch 125, loss: 2.290891
# Epoch 126, loss: 2.288087
# Epoch 127, loss: 2.288174
# Epoch 128, loss: 2.282725
# Epoch 129, loss: 2.292777
# Epoch 130, loss: 2.291702
# Epoch 131, loss: 2.291366
# Epoch 132, loss: 2.292729
# Epoch 133, loss: 2.289244
# Epoch 134, loss: 2.289372
# Epoch 135, loss: 2.289514
# Epoch 136, loss: 2.287924
# Epoch 137, loss: 2.288770
# Epoch 138, loss: 2.287419
# Epoch 139, loss: 2.292294
# Epoch 140, loss: 2.289260
# Epoch 141, loss: 2.289256
# Epoch 142, loss: 2.288662
# Epoch 143, loss: 2.285382
# Epoch 144, loss: 2.283661
# Epoch 145, loss: 2.293378
# Epoch 146, loss: 2.286582
# Epoch 147, loss: 2.292401
# Epoch 148, loss: 2.289151
# Epoch 149, loss: 2.290642
# Epoch 150, loss: 2.290221
# Epoch 151, loss: 2.289871
# Epoch 152, loss: 2.287752
# Epoch 153, loss: 2.292555
# Epoch 154, loss: 2.286707
# Epoch 155, loss: 2.285453
# Epoch 156, loss: 2.288285
# Epoch 157, loss: 2.284827
# Epoch 158, loss: 2.286594
# Epoch 159, loss: 2.287469
# Epoch 160, loss: 2.284581
# Epoch 161, loss: 2.288384
# Epoch 162, loss: 2.285434
# Epoch 163, loss: 2.286141
# Epoch 164, loss: 2.291455
# Epoch 165, loss: 2.289420
# Epoch 166, loss: 2.287297
# Epoch 167, loss: 2.282244
# Epoch 168, loss: 2.284896
# Epoch 169, loss: 2.284880
# Epoch 170, loss: 2.290362
# Epoch 171, loss: 2.285224
# Epoch 172, loss: 2.283389
# Epoch 173, loss: 2.280079
# Epoch 174, loss: 2.291716
# Epoch 175, loss: 2.285276
# Epoch 176, loss: 2.286024
# Epoch 177, loss: 2.286556
# Epoch 178, loss: 2.291560
# Epoch 179, loss: 2.283739
# Epoch 180, loss: 2.285296
# Epoch 181, loss: 2.286241
# Epoch 182, loss: 2.286010
# Epoch 183, loss: 2.289867
# Epoch 184, loss: 2.291838
# Epoch 185, loss: 2.280205
# Epoch 186, loss: 2.287064
# Epoch 187, loss: 2.292507
# Epoch 188, loss: 2.285371
# Epoch 189, loss: 2.285890
# Epoch 190, loss: 2.286695
# Epoch 191, loss: 2.285624
# Epoch 192, loss: 2.283705
# Epoch 193, loss: 2.288043
# Epoch 194, loss: 2.289337
# Epoch 195, loss: 2.284346
# Epoch 196, loss: 2.281727
# Epoch 197, loss: 2.282824
# Epoch 198, loss: 2.284262
# Epoch 199, loss: 2.287112
# Epoch 0, loss: 2.302830
# Epoch 1, loss: 2.302059
# Epoch 2, loss: 2.302521
# Epoch 3, loss: 2.301882
# Epoch 4, loss: 2.302166
# Epoch 5, loss: 2.302052
# Epoch 6, loss: 2.302268
# Epoch 7, loss: 2.301736
# Epoch 8, loss: 2.301205
# Epoch 9, loss: 2.301726
# Epoch 10, loss: 2.301244
# Epoch 11, loss: 2.301999
# Epoch 12, loss: 2.301455
# Epoch 13, loss: 2.301640
# Epoch 14, loss: 2.301529
# Epoch 15, loss: 2.301195
# Epoch 16, loss: 2.301207
# Epoch 17, loss: 2.300269
# Epoch 18, loss: 2.301843
# Epoch 19, loss: 2.300661
# Epoch 20, loss: 2.300486
# Epoch 21, loss: 2.300789
# Epoch 22, loss: 2.300685
# Epoch 23, loss: 2.301858
# Epoch 24, loss: 2.298510
# Epoch 25, loss: 2.300024
# Epoch 26, loss: 2.298872
# Epoch 27, loss: 2.300091
# Epoch 28, loss: 2.300094
# Epoch 29, loss: 2.298861
# Epoch 30, loss: 2.299101
# Epoch 31, loss: 2.299063
# Epoch 32, loss: 2.301664
# Epoch 33, loss: 2.299969
# Epoch 34, loss: 2.298925
# Epoch 35, loss: 2.300274
# Epoch 36, loss: 2.299243
# Epoch 37, loss: 2.297013
# Epoch 38, loss: 2.299966
# Epoch 39, loss: 2.299614
# Epoch 40, loss: 2.298500
# Epoch 41, loss: 2.299448
# Epoch 42, loss: 2.298081
# Epoch 43, loss: 2.299841
# Epoch 44, loss: 2.300060
# Epoch 45, loss: 2.297296
# Epoch 46, loss: 2.298178
# Epoch 47, loss: 2.299152
# Epoch 48, loss: 2.298945
# Epoch 49, loss: 2.299628
# Epoch 50, loss: 2.298300
# Epoch 51, loss: 2.298651
# Epoch 52, loss: 2.295594
# Epoch 53, loss: 2.294846
# Epoch 54, loss: 2.298024
# Epoch 55, loss: 2.298333
# Epoch 56, loss: 2.296474
# Epoch 57, loss: 2.297546
# Epoch 58, loss: 2.294089
# Epoch 59, loss: 2.296443
# Epoch 60, loss: 2.296691
# Epoch 61, loss: 2.299127
# Epoch 62, loss: 2.293329
# Epoch 63, loss: 2.296986
# Epoch 64, loss: 2.295393
# Epoch 65, loss: 2.294988
# Epoch 66, loss: 2.297115
# Epoch 67, loss: 2.298620
# Epoch 68, loss: 2.295614
# Epoch 69, loss: 2.296738
# Epoch 70, loss: 2.294957
# Epoch 71, loss: 2.298569
# Epoch 72, loss: 2.299146
# Epoch 73, loss: 2.297470
# Epoch 74, loss: 2.297519
# Epoch 75, loss: 2.295793
# Epoch 76, loss: 2.297575
# Epoch 77, loss: 2.292449
# Epoch 78, loss: 2.295465
# Epoch 79, loss: 2.293644
# Epoch 80, loss: 2.294951
# Epoch 81, loss: 2.296086
# Epoch 82, loss: 2.294884
# Epoch 83, loss: 2.294401
# Epoch 84, loss: 2.292689
# Epoch 85, loss: 2.292263
# Epoch 86, loss: 2.296390
# Epoch 87, loss: 2.293841
# Epoch 88, loss: 2.292640
# Epoch 89, loss: 2.294909
# Epoch 90, loss: 2.295150
# Epoch 91, loss: 2.289639
# Epoch 92, loss: 2.293651
# Epoch 93, loss: 2.292571
# Epoch 94, loss: 2.293909
# Epoch 95, loss: 2.294118
# Epoch 96, loss: 2.295689
# Epoch 97, loss: 2.292737
# Epoch 98, loss: 2.290473
# Epoch 99, loss: 2.294926
# Epoch 100, loss: 2.296302
# Epoch 101, loss: 2.294266
# Epoch 102, loss: 2.297547
# Epoch 103, loss: 2.295388
# Epoch 104, loss: 2.295426
# Epoch 105, loss: 2.288940
# Epoch 106, loss: 2.293875
# Epoch 107, loss: 2.291809
# Epoch 108, loss: 2.298364
# Epoch 109, loss: 2.291323
# Epoch 110, loss: 2.293860
# Epoch 111, loss: 2.290451
# Epoch 112, loss: 2.293677
# Epoch 113, loss: 2.296447
# Epoch 114, loss: 2.291700
# Epoch 115, loss: 2.290202
# Epoch 116, loss: 2.289489
# Epoch 117, loss: 2.291435
# Epoch 118, loss: 2.291594
# Epoch 119, loss: 2.291814
# Epoch 120, loss: 2.291550
# Epoch 121, loss: 2.291927
# Epoch 122, loss: 2.293737
# Epoch 123, loss: 2.284047
# Epoch 124, loss: 2.292573
# Epoch 125, loss: 2.290744
# Epoch 126, loss: 2.288801
# Epoch 127, loss: 2.291859
# Epoch 128, loss: 2.290918
# Epoch 129, loss: 2.291342
# Epoch 130, loss: 2.288119
# Epoch 131, loss: 2.290745
# Epoch 132, loss: 2.292386
# Epoch 133, loss: 2.289938
# Epoch 134, loss: 2.286762
# Epoch 135, loss: 2.289559
# Epoch 136, loss: 2.293401
# Epoch 137, loss: 2.288717
# Epoch 138, loss: 2.288488
# Epoch 139, loss: 2.292357
# Epoch 140, loss: 2.290486
# Epoch 141, loss: 2.290307
# Epoch 142, loss: 2.284598
# Epoch 143, loss: 2.288380
# Epoch 144, loss: 2.288242
# Epoch 145, loss: 2.285209
# Epoch 146, loss: 2.289858
# Epoch 147, loss: 2.287707
# Epoch 148, loss: 2.291214
# Epoch 149, loss: 2.289607
# Epoch 150, loss: 2.290536
# Epoch 151, loss: 2.286950
# Epoch 152, loss: 2.288084
# Epoch 153, loss: 2.287670
# Epoch 154, loss: 2.288022
# Epoch 155, loss: 2.286910
# Epoch 156, loss: 2.288413
# Epoch 157, loss: 2.293269
# Epoch 158, loss: 2.283727
# Epoch 159, loss: 2.287872
# Epoch 160, loss: 2.284857
# Epoch 161, loss: 2.286026
# Epoch 162, loss: 2.288294
# Epoch 163, loss: 2.290255
# Epoch 164, loss: 2.288868
# Epoch 165, loss: 2.285190
# Epoch 166, loss: 2.288257
# Epoch 167, loss: 2.289682
# Epoch 168, loss: 2.287779
# Epoch 169, loss: 2.285412
# Epoch 170, loss: 2.288396
# Epoch 171, loss: 2.285123
# Epoch 172, loss: 2.285888
# Epoch 173, loss: 2.287895
# Epoch 174, loss: 2.287676
# Epoch 175, loss: 2.287847
# Epoch 176, loss: 2.284852
# Epoch 177, loss: 2.287358
# Epoch 178, loss: 2.288540
# Epoch 179, loss: 2.279896
# Epoch 180, loss: 2.293368
# Epoch 181, loss: 2.288693
# Epoch 182, loss: 2.284890
# Epoch 183, loss: 2.291660
# Epoch 184, loss: 2.283923
# Epoch 185, loss: 2.280574
# Epoch 186, loss: 2.284321
# Epoch 187, loss: 2.285531
# Epoch 188, loss: 2.288272
# Epoch 189, loss: 2.283685
# Epoch 190, loss: 2.286763
# Epoch 191, loss: 2.285465
# Epoch 192, loss: 2.287910
# Epoch 193, loss: 2.289110
# Epoch 194, loss: 2.281626
# Epoch 195, loss: 2.286369
# Epoch 196, loss: 2.281215
# Epoch 197, loss: 2.284682
# Epoch 198, loss: 2.290552
# Epoch 199, loss: 2.281749
# Epoch 0, loss: 2.302619
# Epoch 1, loss: 2.302440
# Epoch 2, loss: 2.303620
# Epoch 3, loss: 2.302807
# Epoch 4, loss: 2.302541
# Epoch 5, loss: 2.303303
# Epoch 6, loss: 2.302485
# Epoch 7, loss: 2.302898
# Epoch 8, loss: 2.301955
# Epoch 9, loss: 2.302569
# Epoch 10, loss: 2.302976
# Epoch 11, loss: 2.302175
# Epoch 12, loss: 2.302851
# Epoch 13, loss: 2.303788
# Epoch 14, loss: 2.303332
# Epoch 15, loss: 2.301714
# Epoch 16, loss: 2.302418
# Epoch 17, loss: 2.302952
# Epoch 18, loss: 2.302428
# Epoch 19, loss: 2.303365
# Epoch 20, loss: 2.302059
# Epoch 21, loss: 2.302814
# Epoch 22, loss: 2.302817
# Epoch 23, loss: 2.302630
# Epoch 24, loss: 2.303254
# Epoch 25, loss: 2.301783
# Epoch 26, loss: 2.301577
# Epoch 27, loss: 2.301732
# Epoch 28, loss: 2.302366
# Epoch 29, loss: 2.302078
# Epoch 30, loss: 2.302188
# Epoch 31, loss: 2.302360
# Epoch 32, loss: 2.302478
# Epoch 33, loss: 2.302499
# Epoch 34, loss: 2.302995
# Epoch 35, loss: 2.302608
# Epoch 36, loss: 2.301707
# Epoch 37, loss: 2.301745
# Epoch 38, loss: 2.302714
# Epoch 39, loss: 2.301462
# Epoch 40, loss: 2.302314
# Epoch 41, loss: 2.301493
# Epoch 42, loss: 2.302258
# Epoch 43, loss: 2.302983
# Epoch 44, loss: 2.302232
# Epoch 45, loss: 2.302313
# Epoch 46, loss: 2.302091
# Epoch 47, loss: 2.301442
# Epoch 48, loss: 2.302386
# Epoch 49, loss: 2.302384
# Epoch 50, loss: 2.303052
# Epoch 51, loss: 2.302009
# Epoch 52, loss: 2.301879
# Epoch 53, loss: 2.301054
# Epoch 54, loss: 2.302293
# Epoch 55, loss: 2.302307
# Epoch 56, loss: 2.302014
# Epoch 57, loss: 2.301627
# Epoch 58, loss: 2.301422
# Epoch 59, loss: 2.301130
# Epoch 60, loss: 2.301730
# Epoch 61, loss: 2.302408
# Epoch 62, loss: 2.301918
# Epoch 63, loss: 2.302687
# Epoch 64, loss: 2.302485
# Epoch 65, loss: 2.301414
# Epoch 66, loss: 2.302743
# Epoch 67, loss: 2.302295
# Epoch 68, loss: 2.301529
# Epoch 69, loss: 2.300454
# Epoch 70, loss: 2.302126
# Epoch 71, loss: 2.301844
# Epoch 72, loss: 2.301672
# Epoch 73, loss: 2.301469
# Epoch 74, loss: 2.302198
# Epoch 75, loss: 2.301721
# Epoch 76, loss: 2.302058
# Epoch 77, loss: 2.302093
# Epoch 78, loss: 2.301901
# Epoch 79, loss: 2.302311
# Epoch 80, loss: 2.301691
# Epoch 81, loss: 2.301609
# Epoch 82, loss: 2.301568
# Epoch 83, loss: 2.301368
# Epoch 84, loss: 2.301315
# Epoch 85, loss: 2.301134
# Epoch 86, loss: 2.301096
# Epoch 87, loss: 2.302763
# Epoch 88, loss: 2.301801
# Epoch 89, loss: 2.302147
# Epoch 90, loss: 2.302130
# Epoch 91, loss: 2.301482
# Epoch 92, loss: 2.301129
# Epoch 93, loss: 2.301188
# Epoch 94, loss: 2.302090
# Epoch 95, loss: 2.301103
# Epoch 96, loss: 2.301841
# Epoch 97, loss: 2.301154
# Epoch 98, loss: 2.301282
# Epoch 99, loss: 2.301849
# Epoch 100, loss: 2.300957
# Epoch 101, loss: 2.301581
# Epoch 102, loss: 2.301763
# Epoch 103, loss: 2.301024
# Epoch 104, loss: 2.300356
# Epoch 105, loss: 2.301257
# Epoch 106, loss: 2.301863
# Epoch 107, loss: 2.301597
# Epoch 108, loss: 2.301772
# Epoch 109, loss: 2.301706
# Epoch 110, loss: 2.300723
# Epoch 111, loss: 2.301544
# Epoch 112, loss: 2.302407
# Epoch 113, loss: 2.301370
# Epoch 114, loss: 2.301306
# Epoch 115, loss: 2.300461
# Epoch 116, loss: 2.300986
# Epoch 117, loss: 2.301612
# Epoch 118, loss: 2.300352
# Epoch 119, loss: 2.301434
# Epoch 120, loss: 2.301388
# Epoch 121, loss: 2.301814
# Epoch 122, loss: 2.300148
# Epoch 123, loss: 2.301445
# Epoch 124, loss: 2.302449
# Epoch 125, loss: 2.301346
# Epoch 126, loss: 2.300655
# Epoch 127, loss: 2.302239
# Epoch 128, loss: 2.301181
# Epoch 129, loss: 2.300454
# Epoch 130, loss: 2.300899
# Epoch 131, loss: 2.301627
# Epoch 132, loss: 2.302393
# Epoch 133, loss: 2.301845
# Epoch 134, loss: 2.301432
# Epoch 135, loss: 2.301392
# Epoch 136, loss: 2.300711
# Epoch 137, loss: 2.301421
# Epoch 138, loss: 2.301853
# Epoch 139, loss: 2.300344
# Epoch 140, loss: 2.301571
# Epoch 141, loss: 2.302648
# Epoch 142, loss: 2.301194
# Epoch 143, loss: 2.302182
# Epoch 144, loss: 2.302367
# Epoch 145, loss: 2.301502
# Epoch 146, loss: 2.300752
# Epoch 147, loss: 2.302340
# Epoch 148, loss: 2.301566
# Epoch 149, loss: 2.300486
# Epoch 150, loss: 2.300849
# Epoch 151, loss: 2.300651
# Epoch 152, loss: 2.300458
# Epoch 153, loss: 2.300251
# Epoch 154, loss: 2.299645
# Epoch 155, loss: 2.301805
# Epoch 156, loss: 2.301422
# Epoch 157, loss: 2.301644
# Epoch 158, loss: 2.300983
# Epoch 159, loss: 2.301392
# Epoch 160, loss: 2.300729
# Epoch 161, loss: 2.300920
# Epoch 162, loss: 2.301397
# Epoch 163, loss: 2.300766
# Epoch 164, loss: 2.300672
# Epoch 165, loss: 2.301275
# Epoch 166, loss: 2.300994
# Epoch 167, loss: 2.300525
# Epoch 168, loss: 2.301673
# Epoch 169, loss: 2.301836
# Epoch 170, loss: 2.300880
# Epoch 171, loss: 2.300807
# Epoch 172, loss: 2.300682
# Epoch 173, loss: 2.301016
# Epoch 174, loss: 2.300601
# Epoch 175, loss: 2.300783
# Epoch 176, loss: 2.300619
# Epoch 177, loss: 2.300707
# Epoch 178, loss: 2.300007
# Epoch 179, loss: 2.300566
# Epoch 180, loss: 2.301531
# Epoch 181, loss: 2.300685
# Epoch 182, loss: 2.300666
# Epoch 183, loss: 2.302052
# Epoch 184, loss: 2.298922
# Epoch 185, loss: 2.301714
# Epoch 186, loss: 2.300172
# Epoch 187, loss: 2.300996
# Epoch 188, loss: 2.301530
# Epoch 189, loss: 2.299574
# Epoch 190, loss: 2.299732
# Epoch 191, loss: 2.299961
# Epoch 192, loss: 2.300611
# Epoch 193, loss: 2.301872
# Epoch 194, loss: 2.299504
# Epoch 195, loss: 2.300287
# Epoch 196, loss: 2.300376
# Epoch 197, loss: 2.301322
# Epoch 198, loss: 2.300419
# Epoch 199, loss: 2.299813
# Epoch 0, loss: 2.302632
# Epoch 1, loss: 2.302383
# Epoch 2, loss: 2.303468
# Epoch 3, loss: 2.302304
# Epoch 4, loss: 2.302347
# Epoch 5, loss: 2.302642
# Epoch 6, loss: 2.302618
# Epoch 7, loss: 2.302694
# Epoch 8, loss: 2.302096
# Epoch 9, loss: 2.301878
# Epoch 10, loss: 2.303113
# Epoch 11, loss: 2.302524
# Epoch 12, loss: 2.301550
# Epoch 13, loss: 2.302753
# Epoch 14, loss: 2.302454
# Epoch 15, loss: 2.301642
# Epoch 16, loss: 2.302278
# Epoch 17, loss: 2.301991
# Epoch 18, loss: 2.301919
# Epoch 19, loss: 2.302451
# Epoch 20, loss: 2.301955
# Epoch 21, loss: 2.302176
# Epoch 22, loss: 2.302189
# Epoch 23, loss: 2.302235
# Epoch 24, loss: 2.302004
# Epoch 25, loss: 2.302178
# Epoch 26, loss: 2.302148
# Epoch 27, loss: 2.301835
# Epoch 28, loss: 2.301328
# Epoch 29, loss: 2.302513
# Epoch 30, loss: 2.301622
# Epoch 31, loss: 2.302124
# Epoch 32, loss: 2.301865
# Epoch 33, loss: 2.302779
# Epoch 34, loss: 2.300972
# Epoch 35, loss: 2.302333
# Epoch 36, loss: 2.302113
# Epoch 37, loss: 2.301791
# Epoch 38, loss: 2.302014
# Epoch 39, loss: 2.302248
# Epoch 40, loss: 2.303231
# Epoch 41, loss: 2.302285
# Epoch 42, loss: 2.301892
# Epoch 43, loss: 2.302132
# Epoch 44, loss: 2.302250
# Epoch 45, loss: 2.302325
# Epoch 46, loss: 2.302452
# Epoch 47, loss: 2.301757
# Epoch 48, loss: 2.302022
# Epoch 49, loss: 2.301828
# Epoch 50, loss: 2.301479
# Epoch 51, loss: 2.302227
# Epoch 52, loss: 2.302210
# Epoch 53, loss: 2.301678
# Epoch 54, loss: 2.302814
# Epoch 55, loss: 2.301489
# Epoch 56, loss: 2.301591
# Epoch 57, loss: 2.301847
# Epoch 58, loss: 2.301318
# Epoch 59, loss: 2.302162
# Epoch 60, loss: 2.300798
# Epoch 61, loss: 2.301449
# Epoch 62, loss: 2.301168
# Epoch 63, loss: 2.301067
# Epoch 64, loss: 2.300976
# Epoch 65, loss: 2.301947
# Epoch 66, loss: 2.302575
# Epoch 67, loss: 2.301168
# Epoch 68, loss: 2.301261
# Epoch 69, loss: 2.302115
# Epoch 70, loss: 2.301576
# Epoch 71, loss: 2.301712
# Epoch 72, loss: 2.301997
# Epoch 73, loss: 2.301108
# Epoch 74, loss: 2.301571
# Epoch 75, loss: 2.301268
# Epoch 76, loss: 2.301417
# Epoch 77, loss: 2.300974
# Epoch 78, loss: 2.301368
# Epoch 79, loss: 2.300757
# Epoch 80, loss: 2.301758
# Epoch 81, loss: 2.300693
# Epoch 82, loss: 2.301565
# Epoch 83, loss: 2.301074
# Epoch 84, loss: 2.301703
# Epoch 85, loss: 2.301567
# Epoch 86, loss: 2.302538
# Epoch 87, loss: 2.300919
# Epoch 88, loss: 2.302122
# Epoch 89, loss: 2.301014
# Epoch 90, loss: 2.301359
# Epoch 91, loss: 2.301517
# Epoch 92, loss: 2.301579
# Epoch 93, loss: 2.300918
# Epoch 94, loss: 2.301127
# Epoch 95, loss: 2.301411
# Epoch 96, loss: 2.301221
# Epoch 97, loss: 2.300849
# Epoch 98, loss: 2.302055
# Epoch 99, loss: 2.299956
# Epoch 100, loss: 2.300649
# Epoch 101, loss: 2.301885
# Epoch 102, loss: 2.302264
# Epoch 103, loss: 2.300931
# Epoch 104, loss: 2.301762
# Epoch 105, loss: 2.301251
# Epoch 106, loss: 2.301973
# Epoch 107, loss: 2.301258
# Epoch 108, loss: 2.301205
# Epoch 109, loss: 2.301126
# Epoch 110, loss: 2.302174
# Epoch 111, loss: 2.301259
# Epoch 112, loss: 2.301752
# Epoch 113, loss: 2.300730
# Epoch 114, loss: 2.301139
# Epoch 115, loss: 2.301230
# Epoch 116, loss: 2.301309
# Epoch 117, loss: 2.300565
# Epoch 118, loss: 2.300706
# Epoch 119, loss: 2.300806
# Epoch 120, loss: 2.301151
# Epoch 121, loss: 2.301076
# Epoch 122, loss: 2.301605
# Epoch 123, loss: 2.300955
# Epoch 124, loss: 2.300643
# Epoch 125, loss: 2.300558
# Epoch 126, loss: 2.301148
# Epoch 127, loss: 2.301021
# Epoch 128, loss: 2.300231
# Epoch 129, loss: 2.300550
# Epoch 130, loss: 2.299813
# Epoch 131, loss: 2.300978
# Epoch 132, loss: 2.301694
# Epoch 133, loss: 2.300724
# Epoch 134, loss: 2.300449
# Epoch 135, loss: 2.302026
# Epoch 136, loss: 2.302422
# Epoch 137, loss: 2.300534
# Epoch 138, loss: 2.301965
# Epoch 139, loss: 2.300690
# Epoch 140, loss: 2.300090
# Epoch 141, loss: 2.300200
# Epoch 142, loss: 2.299812
# Epoch 143, loss: 2.302524
# Epoch 144, loss: 2.300834
# Epoch 145, loss: 2.301026
# Epoch 146, loss: 2.299898
# Epoch 147, loss: 2.300507
# Epoch 148, loss: 2.300842
# Epoch 149, loss: 2.301106
# Epoch 150, loss: 2.300771
# Epoch 151, loss: 2.300739
# Epoch 152, loss: 2.301227
# Epoch 153, loss: 2.299462
# Epoch 154, loss: 2.301297
# Epoch 155, loss: 2.301447
# Epoch 156, loss: 2.299970
# Epoch 157, loss: 2.301377
# Epoch 158, loss: 2.300875
# Epoch 159, loss: 2.302754
# Epoch 160, loss: 2.301675
# Epoch 161, loss: 2.301076
# Epoch 162, loss: 2.300310
# Epoch 163, loss: 2.301641
# Epoch 164, loss: 2.301192
# Epoch 165, loss: 2.302014
# Epoch 166, loss: 2.300613
# Epoch 167, loss: 2.300834
# Epoch 168, loss: 2.301265
# Epoch 169, loss: 2.300284
# Epoch 170, loss: 2.301054
# Epoch 171, loss: 2.300449
# Epoch 172, loss: 2.299812
# Epoch 173, loss: 2.301180
# Epoch 174, loss: 2.301474
# Epoch 175, loss: 2.300916
# Epoch 176, loss: 2.299866
# Epoch 177, loss: 2.300620
# Epoch 178, loss: 2.301609
# Epoch 179, loss: 2.300999
# Epoch 180, loss: 2.300662
# Epoch 181, loss: 2.300330
# Epoch 182, loss: 2.299885
# Epoch 183, loss: 2.301248
# Epoch 184, loss: 2.300814
# Epoch 185, loss: 2.299205
# Epoch 186, loss: 2.299780
# Epoch 187, loss: 2.300201
# Epoch 188, loss: 2.301421
# Epoch 189, loss: 2.299974
# Epoch 190, loss: 2.300546
# Epoch 191, loss: 2.300382
# Epoch 192, loss: 2.300183
# Epoch 193, loss: 2.300987
# Epoch 194, loss: 2.301003
# Epoch 195, loss: 2.299798
# Epoch 196, loss: 2.300168
# Epoch 197, loss: 2.301223
# Epoch 198, loss: 2.301118
# Epoch 199, loss: 2.299924
# Epoch 0, loss: 2.302374
# Epoch 1, loss: 2.302326
# Epoch 2, loss: 2.303031
# Epoch 3, loss: 2.302696
# Epoch 4, loss: 2.303071
# Epoch 5, loss: 2.302719
# Epoch 6, loss: 2.302056
# Epoch 7, loss: 2.302503
# Epoch 8, loss: 2.303099
# Epoch 9, loss: 2.303291
# Epoch 10, loss: 2.302639
# Epoch 11, loss: 2.301866
# Epoch 12, loss: 2.304385
# Epoch 13, loss: 2.302171
# Epoch 14, loss: 2.301418
# Epoch 15, loss: 2.303632
# Epoch 16, loss: 2.302371
# Epoch 17, loss: 2.302759
# Epoch 18, loss: 2.302715
# Epoch 19, loss: 2.302967
# Epoch 20, loss: 2.302050
# Epoch 21, loss: 2.301409
# Epoch 22, loss: 2.302961
# Epoch 23, loss: 2.302788
# Epoch 24, loss: 2.301794
# Epoch 25, loss: 2.301946
# Epoch 26, loss: 2.302082
# Epoch 27, loss: 2.302653
# Epoch 28, loss: 2.302578
# Epoch 29, loss: 2.302353
# Epoch 30, loss: 2.301777
# Epoch 31, loss: 2.302202
# Epoch 32, loss: 2.301120
# Epoch 33, loss: 2.302857
# Epoch 34, loss: 2.300927
# Epoch 35, loss: 2.302072
# Epoch 36, loss: 2.301493
# Epoch 37, loss: 2.302664
# Epoch 38, loss: 2.302251
# Epoch 39, loss: 2.302668
# Epoch 40, loss: 2.302070
# Epoch 41, loss: 2.301394
# Epoch 42, loss: 2.302588
# Epoch 43, loss: 2.301693
# Epoch 44, loss: 2.302451
# Epoch 45, loss: 2.301644
# Epoch 46, loss: 2.301369
# Epoch 47, loss: 2.302212
# Epoch 48, loss: 2.302633
# Epoch 49, loss: 2.303106
# Epoch 50, loss: 2.302405
# Epoch 51, loss: 2.302482
# Epoch 52, loss: 2.301668
# Epoch 53, loss: 2.303091
# Epoch 54, loss: 2.302154
# Epoch 55, loss: 2.301749
# Epoch 56, loss: 2.302408
# Epoch 57, loss: 2.301714
# Epoch 58, loss: 2.301788
# Epoch 59, loss: 2.302150
# Epoch 60, loss: 2.302761
# Epoch 61, loss: 2.303471
# Epoch 62, loss: 2.302187
# Epoch 63, loss: 2.303036
# Epoch 64, loss: 2.302696
# Epoch 65, loss: 2.301786
# Epoch 66, loss: 2.301449
# Epoch 67, loss: 2.301786
# Epoch 68, loss: 2.301546
# Epoch 69, loss: 2.302061
# Epoch 70, loss: 2.301694
# Epoch 71, loss: 2.301676
# Epoch 72, loss: 2.301136
# Epoch 73, loss: 2.301974
# Epoch 74, loss: 2.302284
# Epoch 75, loss: 2.301032
# Epoch 76, loss: 2.302206
# Epoch 77, loss: 2.301832
# Epoch 78, loss: 2.300909
# Epoch 79, loss: 2.301464
# Epoch 80, loss: 2.301973
# Epoch 81, loss: 2.301939
# Epoch 82, loss: 2.301699
# Epoch 83, loss: 2.300885
# Epoch 84, loss: 2.300702
# Epoch 85, loss: 2.303258
# Epoch 86, loss: 2.302229
# Epoch 87, loss: 2.301094
# Epoch 88, loss: 2.302607
# Epoch 89, loss: 2.301543
# Epoch 90, loss: 2.301451
# Epoch 91, loss: 2.301094
# Epoch 92, loss: 2.302554
# Epoch 93, loss: 2.301331
# Epoch 94, loss: 2.302171
# Epoch 95, loss: 2.301252
# Epoch 96, loss: 2.301899
# Epoch 97, loss: 2.300867
# Epoch 98, loss: 2.300867
# Epoch 99, loss: 2.302410
# Epoch 100, loss: 2.302100
# Epoch 101, loss: 2.301176
# Epoch 102, loss: 2.302030
# Epoch 103, loss: 2.302119
# Epoch 104, loss: 2.300267
# Epoch 105, loss: 2.301600
# Epoch 106, loss: 2.301729
# Epoch 107, loss: 2.302263
# Epoch 108, loss: 2.301763
# Epoch 109, loss: 2.301113
# Epoch 110, loss: 2.301335
# Epoch 111, loss: 2.302033
# Epoch 112, loss: 2.301469
# Epoch 113, loss: 2.301373
# Epoch 114, loss: 2.300944
# Epoch 115, loss: 2.300507
# Epoch 116, loss: 2.301795
# Epoch 117, loss: 2.301955
# Epoch 118, loss: 2.302801
# Epoch 119, loss: 2.301218
# Epoch 120, loss: 2.300903
# Epoch 121, loss: 2.301293
# Epoch 122, loss: 2.301003
# Epoch 123, loss: 2.301512
# Epoch 124, loss: 2.302158
# Epoch 125, loss: 2.300756
# Epoch 126, loss: 2.300851
# Epoch 127, loss: 2.300691
# Epoch 128, loss: 2.300966
# Epoch 129, loss: 2.301782
# Epoch 130, loss: 2.300808
# Epoch 131, loss: 2.300029
# Epoch 132, loss: 2.301317
# Epoch 133, loss: 2.300348
# Epoch 134, loss: 2.301912
# Epoch 135, loss: 2.300807
# Epoch 136, loss: 2.301605
# Epoch 137, loss: 2.300451
# Epoch 138, loss: 2.301416
# Epoch 139, loss: 2.300288
# Epoch 140, loss: 2.300361
# Epoch 141, loss: 2.300939
# Epoch 142, loss: 2.300777
# Epoch 143, loss: 2.300174
# Epoch 144, loss: 2.301052
# Epoch 145, loss: 2.301025
# Epoch 146, loss: 2.301117
# Epoch 147, loss: 2.300571
# Epoch 148, loss: 2.301186
# Epoch 149, loss: 2.300746
# Epoch 150, loss: 2.300369
# Epoch 151, loss: 2.301650
# Epoch 152, loss: 2.301303
# Epoch 153, loss: 2.299891
# Epoch 154, loss: 2.300635
# Epoch 155, loss: 2.300888
# Epoch 156, loss: 2.301617
# Epoch 157, loss: 2.300809
# Epoch 158, loss: 2.301408
# Epoch 159, loss: 2.301544
# Epoch 160, loss: 2.301034
# Epoch 161, loss: 2.300759
# Epoch 162, loss: 2.300924
# Epoch 163, loss: 2.301551
# Epoch 164, loss: 2.300959
# Epoch 165, loss: 2.300477
# Epoch 166, loss: 2.301027
# Epoch 167, loss: 2.301123
# Epoch 168, loss: 2.301006
# Epoch 169, loss: 2.301727
# Epoch 170, loss: 2.301124
# Epoch 171, loss: 2.301232
# Epoch 172, loss: 2.300356
# Epoch 173, loss: 2.301751
# Epoch 174, loss: 2.302470
# Epoch 175, loss: 2.301102
# Epoch 176, loss: 2.300200
# Epoch 177, loss: 2.300765
# Epoch 178, loss: 2.300454
# Epoch 179, loss: 2.300760
# Epoch 180, loss: 2.300705
# Epoch 181, loss: 2.299674
# Epoch 182, loss: 2.301040
# Epoch 183, loss: 2.299588
# Epoch 184, loss: 2.301370
# Epoch 185, loss: 2.301166
# Epoch 186, loss: 2.300128
# Epoch 187, loss: 2.300951
# Epoch 188, loss: 2.300575
# Epoch 189, loss: 2.301060
# Epoch 190, loss: 2.300459
# Epoch 191, loss: 2.300640
# Epoch 192, loss: 2.301636
# Epoch 193, loss: 2.300870
# Epoch 194, loss: 2.299940
# Epoch 195, loss: 2.300795
# Epoch 196, loss: 2.300398
# Epoch 197, loss: 2.300080
# Epoch 198, loss: 2.300444
# Epoch 199, loss: 2.300244
# hyper-parameters: lr = 1e-05, rs = 1e-06
# best validation accuracy achieved: 0.228000

# %% [markdown]
# # Какой же точности мы добились на тестовых данных?

# %%
test_pred = best_classifier.predict(test_X)
test_accuracy = multiclass_accuracy(test_pred, test_y)
print('Linear softmax classifier test set accuracy: %f' % (test_accuracy, ))
# Out:
# Linear softmax classifier test set accuracy: 0.195000
